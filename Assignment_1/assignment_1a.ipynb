# %%
# import the necessary packages
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F397CB6DF60>

# %%
edges = cv2.Canny(image,100,200)

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=400x364 at 0x7F39737A7470>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,0,1],[-1,0,1],[-1,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F39737A7A90>

# %% [markdown]
# **Horizontal Kernel**

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel_horizontal = np.float32([[1,1,1],[-2,-2,-2],[1,1,1]])

dst = cv2.filter2D(image,-1,kernel_horizontal)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F3971F51C18>

# %% [markdown]
# **135 degree lines kernel**

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel_45degree = np.float32([[2,-1,-1],[-1,2,-1],[-1,-1,2]])

dst = cv2.filter2D(image,-1,kernel_45degree)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F3971F61AC8>

# %% [markdown]
# **45 Degree Kernel**

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel_45degree = np.float32([[-1,-1,2],[-1,2,-1],[2,-1,-1]])

dst = cv2.filter2D(image,-1,kernel_45degree)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F3971F61E48>

# %% [markdown]
# **Image Blurr Kernel**

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel_blurr = np.ones((3,3))*1/9

dst = cv2.filter2D(image,-1,kernel_blurr)

cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F3971E367F0>

# %% [markdown]
# **Sharpening kernel**

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel_sharpen = np.float32([[-1/9,-1/9,-1/9],[-1/9,17/9,-1/9],[-1/9,-1/9,-1/9]])

dst = cv2.filter2D(image,-1,kernel_sharpen)

cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F3971E41240>

# %% [markdown]
# **Identity Kernel**

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel_sharpen = np.float32([[0, 0, 0],[0, 1, 0],[0, 0, 0]])

dst = cv2.filter2D(image,-1,kernel_sharpen)

cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F3971E36FD0>

# %%
print(dst.shape)

print(image.shape)
# Out:
# (364, 400, 3)
# (364, 400, 3)
