# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')

root_path = 'gdrive/My Drive/Colab Notebooks/' #change dir to your project folder

os.chdir('/content/' + root_path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import keras
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, AveragePooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

#from clr import LRFinder,OneCycleLR
#!git clone https://github.com/bckenstler/CLR.git
  
#from CLR.clr_callback import *

import resnet

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

from keras.layers import GlobalAveragePooling2D

from keras import optimizers

from keras import regularizers

import warnings

warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
train_labels_integer = train_labels

test_labels_integer = test_labels

for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels_integer[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
import numpy as np
from keras.callbacks import Callback

def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
  
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img
      
    return eraser
  
class LR_Finder(Callback):
    
    def __init__(self, start_lr=1e-5, end_lr=10, step_size=None, beta=.98):
        super().__init__()
        
        self.start_lr = start_lr
        self.end_lr = end_lr
        self.step_size = step_size
        self.beta = beta
        self.lr_mult = (end_lr/start_lr)**(1/step_size)
        
    def on_train_begin(self, logs=None):
        self.best_loss = 1e9
        self.avg_loss = 0
        self.losses, self.smoothed_losses, self.lrs, self.iterations = [], [], [], []
        self.iteration = 0
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.start_lr)
        
    def on_batch_end(self, epoch, logs=None):
        logs = logs or {}
        loss = logs.get('loss')
        
        self.iteration += 1
        
        self.avg_loss = self.beta * self.avg_loss + (1 - self.beta) * loss
        smoothed_loss = self.avg_loss / (1 - self.beta**self.iteration)
        
        # Check if the loss is not exploding
        if self.iteration>1 and smoothed_loss > self.best_loss * 3:
            self.model.stop_training = True
            return

        if smoothed_loss < self.best_loss or self.iteration==1:
            self.best_loss = smoothed_loss
        
        lr = self.start_lr * (self.lr_mult**self.iteration)
        
        #print(self.iteration, loss, lr)
        
        self.losses.append(loss)
        self.smoothed_losses.append(smoothed_loss)
        self.lrs.append(lr)
        self.iterations.append(self.iteration)
        
        
        K.set_value(self.model.optimizer.lr, lr)  
        
    def plot_lr(self):
        plt.xlabel('Iterations')
        plt.ylabel('Learning rate')
        plt.plot(self.iterations, self.lrs)
        
    def plot(self, n_skip=10):
        plt.ylabel('Loss')
        plt.xlabel('Learning rate (log scale)')
        plt.plot(self.lrs[n_skip:-5], self.losses[n_skip:-5])
        plt.xscale('log')
        
    def plot_smoothed_loss(self, n_skip=10):
        plt.ylabel('Smoothed Losses')
        plt.xlabel('Learning rate (log scale)')
        plt.plot(self.lrs[n_skip:-5], self.smoothed_losses[n_skip:-5])
        plt.xscale('log')
        
    def plot_loss(self):
        plt.ylabel('Losses')
        plt.xlabel('Iterations')
        plt.plot(self.iterations[10:], self.losses[10:])
        
        
class CyclicLR(keras.callbacks.Callback):
    
    def __init__(self,base_lr, max_lr, step_size, base_m, max_m, cyclical_momentum):
 
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.base_m = base_m
        self.max_m = max_m
        self.cyclical_momentum = cyclical_momentum
        self.step_size = step_size
        
        self.clr_iterations = 0.
        self.cm_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}
        
    def clr(self):
        
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        
        if cycle == 2:
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)          
            return self.base_lr-(self.base_lr-self.base_lr/100)*np.maximum(0,(1-x))
        
        else:
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0,(1-x))
    
    def cm(self):
        
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        
        if cycle == 2:
            
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1) 
            return self.max_m
        
        else:
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
            return self.max_m - (self.max_m-self.base_m)*np.maximum(0,(1-x))
        
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())
            
        if self.cyclical_momentum == True:
            if self.clr_iterations == 0:
                K.set_value(self.model.optimizer.momentum, self.cm())
            else:
                K.set_value(self.model.optimizer.momentum, self.cm())
            
            
    def on_batch_begin(self, batch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)
        
        if self.cyclical_momentum == True:
            self.history.setdefault('momentum', []).append(K.get_value(self.model.optimizer.momentum))

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())
        
        if self.cyclical_momentum == True:
            K.set_value(self.model.optimizer.momentum, self.cm())
        
        
class showLR( Callback ) :
    
    time = time.time()
    
    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 0:
          self.time = time.time()
          
          print("time registered", self.time)
          
        current_time = time.time()
        
        time_taken = current_time - self.time
        lr = float(K.get_value(self.model.optimizer.lr))
        print(" epoch={:02d}, lr={:.5f}, time_elapsed(s)={:.2f}".format( epoch, lr, time_taken))

# %% [markdown]
# **Setting up DataAugmentation**

# %%
datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=True,
                            preprocessing_function=get_random_eraser(v_l=0, v_h=1)
                            )


datagen.fit(train_features)



iterator = datagen.flow(train_features, train_labels, batch_size = train_features.shape[0])

X_train_da, y_train_da = iterator.next()

iterator = datagen.flow(test_features, test_labels, batch_size = test_features.shape[0])

X_test_da, y_test_da = iterator.next()

# %% [markdown]
# **Visualizing augmented images**

# %%
import random

random_images_tolook = [random.randint(0,10000) for x in range(15)]

actual_y = np.argmax(y_test_da, axis=1)

fig, axeslist = plt.subplots(ncols = 3, nrows = len(random_images_tolook)//3 , figsize=(15,8))

for ind in range(len(random_images_tolook)):
  
  axeslist.ravel()[ind].imshow(X_test_da[random_images_tolook[ind]])
  
  axeslist.ravel()[ind].set_title(class_names[actual_y[random_images_tolook[ind]]])
  
plt.subplots_adjust(hspace = 0.5)

# %%
# Define the model

def conv_block(model):
  
  model.add(Convolution2D(64, 3, 3,  border_mode='same')) 
  model.add(Activation('relu'))
  
  model.add(Convolution2D(128, 3, 3, border_mode='same'))
  model.add(Activation('relu'))
  
  model.add(Dropout(0.2))
  
  model.add(Convolution2D(256, 3, 3, border_mode='same'))
  model.add(Activation('relu'))
  
  model.add(Dropout(0.4))
  model.add(Convolution2D(512, 3, 3, border_mode='same'))
  model.add(Activation('relu'))
  
  return model

def transition_block(model):
  

  model.add(Convolution2D(32, 1, 1, border_mode='same'))

  model.add(MaxPooling2D(pool_size=(2, 2)))
  
  return model

model = resnet.ResNet18((train_features.shape[1], train_features.shape[2], train_features.shape[3]), 10)

model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0727 21:27:09.896111 139899605669760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0727 21:27:09.909975 139899605669760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0727 21:27:09.913635 139899605669760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0727 21:27:09.944117 139899605669760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0727 21:27:09.945210 139899605669760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0727 21:27:10.671430 139899605669760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0727 21:27:10.742067 139899605669760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# reshaping via a convolution...
# reshaping via a convolution...
# reshaping via a convolution...
# reshaping via a convolution...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16, 16, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# res0a_branch2a (Conv2D)         (None, 4, 4, 64)     36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 4, 4, 64)     256         res0a_branch2a[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 4, 4, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 4, 4, 64)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4, 4, 64)     256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 4, 4, 64)     36928       activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4, 4, 64)     0           batch_normalization_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, 4, 64)     256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 4, 4, 64)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 64)     36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 4, 4, 64)     256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 4, 4, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 4, 64)     36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 4, 4, 64)     0           add_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 4, 64)     256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 4, 4, 64)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 2, 2, 128)    73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 2, 2, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 2, 2, 128)    8320        add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 2, 2, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 2, 2, 128)    512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 2, 2, 128)    147584      activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 2, 2, 128)    0           batch_normalization_8[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 2, 2, 128)    512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 2, 2, 128)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 2, 2, 128)    147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 2, 2, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 2, 2, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 2, 2, 128)    147584      activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 2, 2, 128)    0           add_3[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 2, 2, 128)    512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 1, 256)    295168      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 1, 1, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 256)    33024       add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 1, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 1, 1, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 1, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 1, 1, 256)    0           batch_normalization_13[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1, 1, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 1, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 1, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1, 1, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 1, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1, 1, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 1, 1, 256)    0           add_5[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1, 1, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 1, 1, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 1, 512)    1180160     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 1, 1, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 1, 512)    131584      add_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1, 1, 512)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 1, 1, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 1, 1, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 1, 1, 512)    0           batch_normalization_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 1, 1, 512)    2048        add_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1, 1, 512)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 1, 1, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 1, 1, 512)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 1, 512)    2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1, 1, 512)    0           add_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 1, 1, 512)    2048        add_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 1, 1, 512)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           activation_17[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 11,200,458
# Trainable params: 11,190,730
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %%
# Compile the model

sgd = optimizers.SGD(lr=0.01,  momentum=0.9)


model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

# train the model
start = time.time()
# Train the model

bs = int(128 * 4)


step_size_clr = int(train_features.shape[0])//bs

lr_finder = LR_Finder(start_lr=1e-8, end_lr=10, step_size=step_size_clr)
"""
lr_finder = LRFinder(train_features.shape[0], bs,
                       1e-8, 1,
                       # validation_data=(X_val, Y_val),
                       lr_scale='exp', save_dir='.', verbose=0)
                       
"""


model_info = model.fit_generator(datagen.flow(X_train_da, y_train_da, batch_size = bs),
                                 samples_per_epoch = train_features.shape[0], 
                                 callbacks=[lr_finder] ,verbose=0)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

#lr_finder.plot_schedule()
lr_finder.plot_smoothed_loss()
# Out:
# W0727 21:27:12.718248 139899605669760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0727 21:27:13.081662 139899605669760 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model took 16.56 seconds to train

# %% [markdown]
# **Setting up the learning rate and callbacks**

# %%
"""lr_manager = OneCycleLR(max_lr = 10e-7,
                        end_percentage=0.1, scale_percentage=None,
                        maximum_momentum=0.95, minimum_momentum=0.85)
                        
                        """
epochs = 100
max_lr = 0.1
base_lr = 0.008
max_m = 0.98
base_m = 0.85

cyclical_momentum = True
augment = True
cycles = 7

iterations = int(train_features.shape[0])//bs*epochs
iterations = list(range(0,iterations+1))
step_size_clr = len(iterations)/(cycles)


#lr_manager = CyclicLR(base_lr = .003, max_lr = 0.1, step_size = step_size_clr, mode="triangular")

lr_manager =  CyclicLR(base_lr=base_lr,
                max_lr=max_lr,
                step_size=step_size_clr,
                max_m=max_m,
                base_m=base_m,
                cyclical_momentum=cyclical_momentum)

filepath = "assignment_12_eva.hdf5"

checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

sgd = optimizers.SGD(lr=base_lr,  momentum=0.9)

showlr = showLR()

# %% [markdown]
# **Train for 5 epochs to test if model is actually converging**

# %%
print(K.get_value(model.optimizer.lr))

model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])


# train the model
start = time.time()

model_info = model.fit_generator(datagen.flow(X_train_da, y_train_da, batch_size = bs),
                                 samples_per_epoch = int(train_features.shape[0]), nb_epoch = epochs, 
                                 validation_data = (test_features, test_labels), callbacks=[checkpoint, lr_manager, showlr] ,verbose=1)

end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(model_info)

model.load_weights(filepath)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# 10.0
# Epoch 1/100
# time registered 1564262853.3408678
#  epoch=00, lr=0.00800, time_elapsed(s)=0.00
# 97/97 [==============================] - 11s 112ms/step - loss: 4.0318 - acc: 0.1343 - val_loss: 7.5625 - val_acc: 0.1406
#
# Epoch 00001: val_acc improved from -inf to 0.14060, saving model to assignment_12_eva.hdf5
# Epoch 2/100
#  epoch=01, lr=0.01352, time_elapsed(s)=16.27
# 97/97 [==============================] - 10s 100ms/step - loss: 3.7517 - acc: 0.1795 - val_loss: 3.8038 - val_acc: 0.1429
#
# Epoch 00002: val_acc improved from 0.14060 to 0.14290, saving model to assignment_12_eva.hdf5
# Epoch 3/100
#  epoch=02, lr=0.01904, time_elapsed(s)=27.90
# 97/97 [==============================] - 7s 77ms/step - loss: 3.6529 - acc: 0.1879 - val_loss: 3.6630 - val_acc: 0.1790
#
# Epoch 00003: val_acc improved from 0.14290 to 0.17900, saving model to assignment_12_eva.hdf5
# Epoch 4/100
#  epoch=03, lr=0.02456, time_elapsed(s)=35.83
# 97/97 [==============================] - 7s 77ms/step - loss: 3.5775 - acc: 0.2109 - val_loss: 3.6617 - val_acc: 0.1644
#
# Epoch 00004: val_acc did not improve from 0.17900
# Epoch 5/100
#  epoch=04, lr=0.03008, time_elapsed(s)=43.28
# 97/97 [==============================] - 7s 76ms/step - loss: 3.4818 - acc: 0.2283 - val_loss: 3.4636 - val_acc: 0.2104
#
# Epoch 00005: val_acc improved from 0.17900 to 0.21040, saving model to assignment_12_eva.hdf5
# Epoch 6/100
#  epoch=05, lr=0.03560, time_elapsed(s)=52.57
# 97/97 [==============================] - 7s 77ms/step - loss: 3.3986 - acc: 0.2430 - val_loss: 3.3383 - val_acc: 0.2417
#
# Epoch 00006: val_acc improved from 0.21040 to 0.24170, saving model to assignment_12_eva.hdf5
# Epoch 7/100
#  epoch=06, lr=0.04112, time_elapsed(s)=60.48
# 97/97 [==============================] - 7s 76ms/step - loss: 3.3123 - acc: 0.2573 - val_loss: 3.3620 - val_acc: 0.2464
#
# Epoch 00007: val_acc improved from 0.24170 to 0.24640, saving model to assignment_12_eva.hdf5
# Epoch 8/100
#  epoch=07, lr=0.04664, time_elapsed(s)=68.28
# 97/97 [==============================] - 7s 76ms/step - loss: 3.2358 - acc: 0.2748 - val_loss: 3.2692 - val_acc: 0.2482
#
# Epoch 00008: val_acc improved from 0.24640 to 0.24820, saving model to assignment_12_eva.hdf5
# Epoch 9/100
#  epoch=08, lr=0.05216, time_elapsed(s)=76.11
# 97/97 [==============================] - 7s 76ms/step - loss: 3.1637 - acc: 0.2888 - val_loss: 3.1597 - val_acc: 0.2853
#
# Epoch 00009: val_acc improved from 0.24820 to 0.28530, saving model to assignment_12_eva.hdf5
# Epoch 10/100
#  epoch=09, lr=0.05767, time_elapsed(s)=83.93
# 97/97 [==============================] - 7s 76ms/step - loss: 3.0872 - acc: 0.2988 - val_loss: 3.0423 - val_acc: 0.3078
#
# Epoch 00010: val_acc improved from 0.28530 to 0.30780, saving model to assignment_12_eva.hdf5
# Epoch 11/100
#  epoch=10, lr=0.06319, time_elapsed(s)=91.71
# 97/97 [==============================] - 7s 77ms/step - loss: 3.0172 - acc: 0.3167 - val_loss: 3.0393 - val_acc: 0.2905
#
# Epoch 00011: val_acc did not improve from 0.30780
# Epoch 12/100
#  epoch=11, lr=0.06871, time_elapsed(s)=99.18
# 97/97 [==============================] - 7s 77ms/step - loss: 2.9413 - acc: 0.3358 - val_loss: 2.8992 - val_acc: 0.3502
#
# Epoch 00012: val_acc improved from 0.30780 to 0.35020, saving model to assignment_12_eva.hdf5
# Epoch 13/100
#  epoch=12, lr=0.07423, time_elapsed(s)=108.73
# 97/97 [==============================] - 8s 78ms/step - loss: 2.8884 - acc: 0.3540 - val_loss: 2.8814 - val_acc: 0.3552
#
# Epoch 00013: val_acc improved from 0.35020 to 0.35520, saving model to assignment_12_eva.hdf5
# Epoch 14/100
#  epoch=13, lr=0.07975, time_elapsed(s)=116.76
# 97/97 [==============================] - 7s 76ms/step - loss: 2.8077 - acc: 0.3780 - val_loss: 2.8435 - val_acc: 0.3382
#
# Epoch 00014: val_acc did not improve from 0.35520
# Epoch 15/100
#  epoch=14, lr=0.08527, time_elapsed(s)=124.13
# 97/97 [==============================] - 7s 77ms/step - loss: 2.7539 - acc: 0.3993 - val_loss: 2.8050 - val_acc: 0.3847
#
# Epoch 00015: val_acc improved from 0.35520 to 0.38470, saving model to assignment_12_eva.hdf5
# Epoch 16/100
#  epoch=15, lr=0.09079, time_elapsed(s)=133.58
# 97/97 [==============================] - 7s 77ms/step - loss: 2.6543 - acc: 0.4262 - val_loss: 2.7481 - val_acc: 0.3775
#
# Epoch 00016: val_acc did not improve from 0.38470
# Epoch 17/100
#  epoch=16, lr=0.09631, time_elapsed(s)=141.02
# 97/97 [==============================] - 7s 76ms/step - loss: 2.6085 - acc: 0.4358 - val_loss: 2.8335 - val_acc: 0.3680
#
# Epoch 00017: val_acc did not improve from 0.38470
# Epoch 18/100
#  epoch=17, lr=0.09817, time_elapsed(s)=148.39
# 97/97 [==============================] - 7s 76ms/step - loss: 2.5653 - acc: 0.4535 - val_loss: 2.6190 - val_acc: 0.4145
#
# Epoch 00018: val_acc improved from 0.38470 to 0.41450, saving model to assignment_12_eva.hdf5
# Epoch 19/100
#  epoch=18, lr=0.09265, time_elapsed(s)=157.71
# 97/97 [==============================] - 7s 77ms/step - loss: 2.4861 - acc: 0.4693 - val_loss: 2.5884 - val_acc: 0.4260
#
# Epoch 00019: val_acc improved from 0.41450 to 0.42600, saving model to assignment_12_eva.hdf5
# Epoch 20/100
#  epoch=19, lr=0.08713, time_elapsed(s)=165.62
# 97/97 [==============================] - 7s 76ms/step - loss: 2.4307 - acc: 0.4825 - val_loss: 2.3994 - val_acc: 0.4784
#
# Epoch 00020: val_acc improved from 0.42600 to 0.47840, saving model to assignment_12_eva.hdf5
# Epoch 21/100
#  epoch=20, lr=0.08161, time_elapsed(s)=173.44
# 97/97 [==============================] - 7s 77ms/step - loss: 2.3794 - acc: 0.4944 - val_loss: 2.5543 - val_acc: 0.4341
#
# Epoch 00021: val_acc did not improve from 0.47840
# Epoch 22/100
#  epoch=21, lr=0.07609, time_elapsed(s)=180.89
# 97/97 [==============================] - 7s 76ms/step - loss: 2.3286 - acc: 0.5054 - val_loss: 2.3768 - val_acc: 0.4916
#
# Epoch 00022: val_acc improved from 0.47840 to 0.49160, saving model to assignment_12_eva.hdf5
# Epoch 23/100
#  epoch=22, lr=0.07057, time_elapsed(s)=190.25
# 97/97 [==============================] - 7s 77ms/step - loss: 2.2543 - acc: 0.5246 - val_loss: 2.2316 - val_acc: 0.5233
#
# Epoch 00023: val_acc improved from 0.49160 to 0.52330, saving model to assignment_12_eva.hdf5
# Epoch 24/100
#  epoch=23, lr=0.06505, time_elapsed(s)=198.18
# 97/97 [==============================] - 7s 76ms/step - loss: 2.2067 - acc: 0.5353 - val_loss: 2.5026 - val_acc: 0.4378
#
# Epoch 00024: val_acc did not improve from 0.52330
# Epoch 25/100
#  epoch=24, lr=0.05953, time_elapsed(s)=205.59
# 97/97 [==============================] - 7s 77ms/step - loss: 2.1595 - acc: 0.5449 - val_loss: 2.2356 - val_acc: 0.5115
#
# Epoch 00025: val_acc did not improve from 0.52330
# Epoch 26/100
#  epoch=25, lr=0.05401, time_elapsed(s)=213.08
# 97/97 [==============================] - 7s 76ms/step - loss: 2.1279 - acc: 0.5506 - val_loss: 2.1545 - val_acc: 0.5297
#
# Epoch 00026: val_acc improved from 0.52330 to 0.52970, saving model to assignment_12_eva.hdf5
# Epoch 27/100
#  epoch=26, lr=0.04849, time_elapsed(s)=222.36
# 97/97 [==============================] - 7s 77ms/step - loss: 2.0750 - acc: 0.5638 - val_loss: 2.0627 - val_acc: 0.5592
#
# Epoch 00027: val_acc improved from 0.52970 to 0.55920, saving model to assignment_12_eva.hdf5
# Epoch 28/100
#  epoch=27, lr=0.04298, time_elapsed(s)=230.29
# 97/97 [==============================] - 7s 76ms/step - loss: 2.0463 - acc: 0.5693 - val_loss: 2.0702 - val_acc: 0.5465
#
# Epoch 00028: val_acc did not improve from 0.55920
# Epoch 29/100
#  epoch=28, lr=0.03746, time_elapsed(s)=237.64
# 97/97 [==============================] - 7s 76ms/step - loss: 2.0038 - acc: 0.5761 - val_loss: 2.4001 - val_acc: 0.4335
#
# Epoch 00029: val_acc did not improve from 0.55920
# Epoch 30/100
#  epoch=29, lr=0.03194, time_elapsed(s)=245.04
# 97/97 [==============================] - 7s 76ms/step - loss: 1.9666 - acc: 0.5865 - val_loss: 1.8912 - val_acc: 0.6175
#
# Epoch 00030: val_acc improved from 0.55920 to 0.61750, saving model to assignment_12_eva.hdf5
# Epoch 31/100
#  epoch=30, lr=0.02642, time_elapsed(s)=254.44
# 97/97 [==============================] - 7s 76ms/step - loss: 1.9294 - acc: 0.5925 - val_loss: 1.8930 - val_acc: 0.6024
#
# Epoch 00031: val_acc did not improve from 0.61750
# Epoch 32/100
#  epoch=31, lr=0.02090, time_elapsed(s)=261.85
# 97/97 [==============================] - 7s 76ms/step - loss: 1.8826 - acc: 0.6089 - val_loss: 2.0058 - val_acc: 0.5714
#
# Epoch 00032: val_acc did not improve from 0.61750
# Epoch 33/100
#  epoch=32, lr=0.01538, time_elapsed(s)=269.24
# 97/97 [==============================] - 7s 76ms/step - loss: 1.8685 - acc: 0.6081 - val_loss: 2.0213 - val_acc: 0.5669
#
# Epoch 00033: val_acc did not improve from 0.61750
# Epoch 34/100
#  epoch=33, lr=0.00986, time_elapsed(s)=276.61
# 97/97 [==============================] - 7s 76ms/step - loss: 1.8375 - acc: 0.6126 - val_loss: 1.8015 - val_acc: 0.6403
#
# Epoch 00034: val_acc improved from 0.61750 to 0.64030, saving model to assignment_12_eva.hdf5
# Epoch 35/100
#  epoch=34, lr=0.00768, time_elapsed(s)=286.14
# 97/97 [==============================] - 7s 77ms/step - loss: 1.7912 - acc: 0.6268 - val_loss: 1.7065 - val_acc: 0.6606
#
# Epoch 00035: val_acc improved from 0.64030 to 0.66060, saving model to assignment_12_eva.hdf5
# Epoch 36/100
#  epoch=35, lr=0.00721, time_elapsed(s)=294.03
# 97/97 [==============================] - 7s 77ms/step - loss: 1.7665 - acc: 0.6351 - val_loss: 1.8682 - val_acc: 0.6167
#
# Epoch 00036: val_acc did not improve from 0.66060
# Epoch 37/100
#  epoch=36, lr=0.00673, time_elapsed(s)=301.49
# 97/97 [==============================] - 7s 76ms/step - loss: 1.7372 - acc: 0.6433 - val_loss: 1.8709 - val_acc: 0.5959
#
# Epoch 00037: val_acc did not improve from 0.66060
# Epoch 38/100
#  epoch=37, lr=0.00626, time_elapsed(s)=308.85
# 97/97 [==============================] - 7s 76ms/step - loss: 1.7297 - acc: 0.6411 - val_loss: 1.6949 - val_acc: 0.6532
#
# Epoch 00038: val_acc did not improve from 0.66060
# Epoch 39/100
#  epoch=38, lr=0.00578, time_elapsed(s)=316.23
# 97/97 [==============================] - 7s 76ms/step - loss: 1.6953 - acc: 0.6495 - val_loss: 1.6666 - val_acc: 0.6582
#
# Epoch 00039: val_acc did not improve from 0.66060
# Epoch 40/100
#  epoch=39, lr=0.00531, time_elapsed(s)=323.63
# 97/97 [==============================] - 7s 76ms/step - loss: 1.6827 - acc: 0.6549 - val_loss: 1.7562 - val_acc: 0.6287
#
# Epoch 00040: val_acc did not improve from 0.66060
# Epoch 41/100
#  epoch=40, lr=0.00483, time_elapsed(s)=331.02
# 97/97 [==============================] - 7s 76ms/step - loss: 1.6684 - acc: 0.6559 - val_loss: 1.7920 - val_acc: 0.6171
#
# Epoch 00041: val_acc did not improve from 0.66060
# Epoch 42/100
#  epoch=41, lr=0.00436, time_elapsed(s)=338.36
# 97/97 [==============================] - 7s 76ms/step - loss: 1.6465 - acc: 0.6632 - val_loss: 1.6229 - val_acc: 0.6731
#
# Epoch 00042: val_acc improved from 0.66060 to 0.67310, saving model to assignment_12_eva.hdf5
# Epoch 43/100
#  epoch=42, lr=0.00388, time_elapsed(s)=347.73
# 97/97 [==============================] - 7s 77ms/step - loss: 1.6272 - acc: 0.6680 - val_loss: 1.6464 - val_acc: 0.6585
#
# Epoch 00043: val_acc did not improve from 0.67310
# Epoch 44/100
#  epoch=43, lr=0.00341, time_elapsed(s)=355.18
# 97/97 [==============================] - 7s 76ms/step - loss: 1.6098 - acc: 0.6700 - val_loss: 1.5877 - val_acc: 0.6855
#
# Epoch 00044: val_acc improved from 0.67310 to 0.68550, saving model to assignment_12_eva.hdf5
# Epoch 45/100
#  epoch=44, lr=0.00293, time_elapsed(s)=364.48
# 97/97 [==============================] - 7s 77ms/step - loss: 1.5946 - acc: 0.6758 - val_loss: 1.5731 - val_acc: 0.6833
#
# Epoch 00045: val_acc did not improve from 0.68550
# Epoch 46/100
#  epoch=45, lr=0.00246, time_elapsed(s)=371.96
# 97/97 [==============================] - 7s 76ms/step - loss: 1.5772 - acc: 0.6824 - val_loss: 1.5785 - val_acc: 0.6860
#
# Epoch 00046: val_acc improved from 0.68550 to 0.68600, saving model to assignment_12_eva.hdf5
# Epoch 47/100
#  epoch=46, lr=0.00198, time_elapsed(s)=381.27
# 97/97 [==============================] - 7s 77ms/step - loss: 1.5643 - acc: 0.6850 - val_loss: 1.5301 - val_acc: 0.6957
#
# Epoch 00047: val_acc improved from 0.68600 to 0.69570, saving model to assignment_12_eva.hdf5
# Epoch 48/100
#  epoch=47, lr=0.00151, time_elapsed(s)=389.21
# 97/97 [==============================] - 7s 76ms/step - loss: 1.5628 - acc: 0.6857 - val_loss: 1.5236 - val_acc: 0.7047
#
# Epoch 00048: val_acc improved from 0.69570 to 0.70470, saving model to assignment_12_eva.hdf5
# Epoch 49/100
#  epoch=48, lr=0.00103, time_elapsed(s)=397.02
# 97/97 [==============================] - 7s 77ms/step - loss: 1.5483 - acc: 0.6875 - val_loss: 1.5313 - val_acc: 0.6975
#
# Epoch 00049: val_acc did not improve from 0.70470
# Epoch 50/100
#  epoch=49, lr=0.00056, time_elapsed(s)=404.46
# 97/97 [==============================] - 7s 77ms/step - loss: 1.5392 - acc: 0.6895 - val_loss: 1.5332 - val_acc: 0.6997
#
# Epoch 00050: val_acc did not improve from 0.70470
# Epoch 51/100
#  epoch=50, lr=0.00008, time_elapsed(s)=411.92
# 97/97 [==============================] - 7s 76ms/step - loss: 1.5301 - acc: 0.6925 - val_loss: 1.5004 - val_acc: 0.7132
#
# Epoch 00051: val_acc improved from 0.70470 to 0.71320, saving model to assignment_12_eva.hdf5
# Epoch 52/100
#  epoch=51, lr=0.00055, time_elapsed(s)=421.32
# 97/97 [==============================] - 7s 77ms/step - loss: 1.5334 - acc: 0.6928 - val_loss: 1.5054 - val_acc: 0.7105
#
# Epoch 00052: val_acc did not improve from 0.71320
# Epoch 53/100
#  epoch=52, lr=0.00103, time_elapsed(s)=428.75
# 97/97 [==============================] - 7s 77ms/step - loss: 1.5305 - acc: 0.6942 - val_loss: 1.5174 - val_acc: 0.7004
#
# Epoch 00053: val_acc did not improve from 0.71320
# Epoch 54/100
#  epoch=53, lr=0.00150, time_elapsed(s)=436.19
# 97/97 [==============================] - 7s 76ms/step - loss: 1.5296 - acc: 0.6913 - val_loss: 1.5158 - val_acc: 0.7014
#
# Epoch 00054: val_acc did not improve from 0.71320
# Epoch 55/100
#  epoch=54, lr=0.00198, time_elapsed(s)=443.54
# 97/97 [==============================] - 7s 76ms/step - loss: 1.5443 - acc: 0.6876 - val_loss: 1.6083 - val_acc: 0.6679
#
# Epoch 00055: val_acc did not improve from 0.71320
# Epoch 56/100
#  epoch=55, lr=0.00245, time_elapsed(s)=450.89
# 97/97 [==============================] - 7s 75ms/step - loss: 1.5353 - acc: 0.6892 - val_loss: 1.5588 - val_acc: 0.6808
#
# Epoch 00056: val_acc did not improve from 0.71320
# Epoch 57/100
#  epoch=56, lr=0.00293, time_elapsed(s)=458.21
# 97/97 [==============================] - 7s 75ms/step - loss: 1.5263 - acc: 0.6918 - val_loss: 1.5227 - val_acc: 0.6942
#
# Epoch 00057: val_acc did not improve from 0.71320
# Epoch 58/100
#  epoch=57, lr=0.00340, time_elapsed(s)=465.53
# 97/97 [==============================] - 7s 75ms/step - loss: 1.5317 - acc: 0.6906 - val_loss: 1.5603 - val_acc: 0.6832
#
# Epoch 00058: val_acc did not improve from 0.71320
# Epoch 59/100
#  epoch=58, lr=0.00388, time_elapsed(s)=472.85
# 97/97 [==============================] - 7s 75ms/step - loss: 1.5299 - acc: 0.6875 - val_loss: 1.5722 - val_acc: 0.6741
#
# Epoch 00059: val_acc did not improve from 0.71320
# Epoch 60/100
#  epoch=59, lr=0.00435, time_elapsed(s)=480.17
# 97/97 [==============================] - 7s 76ms/step - loss: 1.5182 - acc: 0.6924 - val_loss: 1.7268 - val_acc: 0.6371
#
# Epoch 00060: val_acc did not improve from 0.71320
# Epoch 61/100
#  epoch=60, lr=0.00483, time_elapsed(s)=487.57
# 97/97 [==============================] - 7s 76ms/step - loss: 1.5260 - acc: 0.6871 - val_loss: 1.5541 - val_acc: 0.6747
#
# Epoch 00061: val_acc did not improve from 0.71320
# Epoch 62/100
#  epoch=61, lr=0.00530, time_elapsed(s)=494.94
# 97/97 [==============================] - 7s 75ms/step - loss: 1.5131 - acc: 0.6882 - val_loss: 1.5284 - val_acc: 0.6779
#
# Epoch 00062: val_acc did not improve from 0.71320
# Epoch 63/100
#  epoch=62, lr=0.00578, time_elapsed(s)=502.26
# 97/97 [==============================] - 7s 76ms/step - loss: 1.5077 - acc: 0.6871 - val_loss: 1.6143 - val_acc: 0.6506
#
# Epoch 00063: val_acc did not improve from 0.71320
# Epoch 64/100
#  epoch=63, lr=0.00625, time_elapsed(s)=509.61
# 97/97 [==============================] - 7s 76ms/step - loss: 1.4892 - acc: 0.6936 - val_loss: 1.5196 - val_acc: 0.6761
#
# Epoch 00064: val_acc did not improve from 0.71320
# Epoch 65/100
#  epoch=64, lr=0.00673, time_elapsed(s)=516.96
# 97/97 [==============================] - 7s 75ms/step - loss: 1.4907 - acc: 0.6903 - val_loss: 1.5357 - val_acc: 0.6723
#
# Epoch 00065: val_acc did not improve from 0.71320
# Epoch 66/100
#  epoch=65, lr=0.00720, time_elapsed(s)=524.28
# 97/97 [==============================] - 7s 76ms/step - loss: 1.4823 - acc: 0.6922 - val_loss: 1.5769 - val_acc: 0.6601
#
# Epoch 00066: val_acc did not improve from 0.71320
# Epoch 67/100
#  epoch=66, lr=0.00768, time_elapsed(s)=531.62
# 97/97 [==============================] - 7s 76ms/step - loss: 1.4907 - acc: 0.6852 - val_loss: 1.5428 - val_acc: 0.6664
#
# Epoch 00067: val_acc did not improve from 0.71320
# Epoch 68/100
#  epoch=67, lr=0.00980, time_elapsed(s)=538.97
# 97/97 [==============================] - 7s 76ms/step - loss: 1.4707 - acc: 0.6918 - val_loss: 1.8213 - val_acc: 0.5801
#
# Epoch 00068: val_acc did not improve from 0.71320
# Epoch 69/100
#  epoch=68, lr=0.01532, time_elapsed(s)=546.30
# 97/97 [==============================] - 7s 76ms/step - loss: 1.4831 - acc: 0.6833 - val_loss: 1.7402 - val_acc: 0.6001
#
# Epoch 00069: val_acc did not improve from 0.71320
# Epoch 70/100
#  epoch=69, lr=0.02084, time_elapsed(s)=553.65
# 97/97 [==============================] - 7s 76ms/step - loss: 1.4764 - acc: 0.6837 - val_loss: 1.6694 - val_acc: 0.6250
#
# Epoch 00070: val_acc did not improve from 0.71320
# Epoch 71/100
#  epoch=70, lr=0.02636, time_elapsed(s)=560.98
# 97/97 [==============================] - 7s 76ms/step - loss: 1.4669 - acc: 0.6829 - val_loss: 1.4506 - val_acc: 0.6844
#
# Epoch 00071: val_acc did not improve from 0.71320
# Epoch 72/100
#  epoch=71, lr=0.03188, time_elapsed(s)=568.33
# 97/97 [==============================] - 7s 75ms/step - loss: 1.4274 - acc: 0.6928 - val_loss: 1.4823 - val_acc: 0.6766
#
# Epoch 00072: val_acc did not improve from 0.71320
# Epoch 73/100
#  epoch=72, lr=0.03740, time_elapsed(s)=575.65
# 97/97 [==============================] - 7s 76ms/step - loss: 1.4255 - acc: 0.6906 - val_loss: 1.6207 - val_acc: 0.6368
#
# Epoch 00073: val_acc did not improve from 0.71320
# Epoch 74/100
#  epoch=73, lr=0.04292, time_elapsed(s)=583.03
# 97/97 [==============================] - 7s 76ms/step - loss: 1.3988 - acc: 0.6948 - val_loss: 1.8176 - val_acc: 0.5686
#
# Epoch 00074: val_acc did not improve from 0.71320
# Epoch 75/100
#  epoch=74, lr=0.04844, time_elapsed(s)=590.41
# 97/97 [==============================] - 7s 76ms/step - loss: 1.3838 - acc: 0.6976 - val_loss: 1.4951 - val_acc: 0.6576
#
# Epoch 00075: val_acc did not improve from 0.71320
# Epoch 76/100
#  epoch=75, lr=0.05396, time_elapsed(s)=597.74
# 97/97 [==============================] - 7s 76ms/step - loss: 1.3651 - acc: 0.7012 - val_loss: 1.6832 - val_acc: 0.6210
#
# Epoch 00076: val_acc did not improve from 0.71320
# Epoch 77/100
#  epoch=76, lr=0.05948, time_elapsed(s)=605.08
# 97/97 [==============================] - 7s 75ms/step - loss: 1.3606 - acc: 0.7001 - val_loss: 3.7077 - val_acc: 0.3471
#
# Epoch 00077: val_acc did not improve from 0.71320
# Epoch 78/100
#  epoch=77, lr=0.06500, time_elapsed(s)=612.40
# 97/97 [==============================] - 7s 76ms/step - loss: 1.4185 - acc: 0.6789 - val_loss: 1.6577 - val_acc: 0.6040
#
# Epoch 00078: val_acc did not improve from 0.71320
# Epoch 79/100
#  epoch=78, lr=0.07052, time_elapsed(s)=619.75
# 97/97 [==============================] - 7s 76ms/step - loss: 1.3290 - acc: 0.7073 - val_loss: 2.0594 - val_acc: 0.4693
#
# Epoch 00079: val_acc did not improve from 0.71320
# Epoch 80/100
#  epoch=79, lr=0.07604, time_elapsed(s)=627.16
# 97/97 [==============================] - 7s 76ms/step - loss: 1.3114 - acc: 0.7091 - val_loss: 1.5653 - val_acc: 0.6393
#
# Epoch 00080: val_acc did not improve from 0.71320
# Epoch 81/100
#  epoch=80, lr=0.08155, time_elapsed(s)=634.53
# 97/97 [==============================] - 7s 76ms/step - loss: 1.2908 - acc: 0.7131 - val_loss: 1.4074 - val_acc: 0.6717
#
# Epoch 00081: val_acc did not improve from 0.71320
# Epoch 82/100
#  epoch=81, lr=0.08707, time_elapsed(s)=641.86
# 97/97 [==============================] - 7s 75ms/step - loss: 1.2816 - acc: 0.7139 - val_loss: 1.3786 - val_acc: 0.6799
#
# Epoch 00082: val_acc did not improve from 0.71320
# Epoch 83/100
#  epoch=82, lr=0.09259, time_elapsed(s)=649.18
# 97/97 [==============================] - 7s 76ms/step - loss: 1.2606 - acc: 0.7172 - val_loss: 1.3955 - val_acc: 0.6740
#
# Epoch 00083: val_acc did not improve from 0.71320
# Epoch 84/100
#  epoch=83, lr=0.09811, time_elapsed(s)=656.54
# 97/97 [==============================] - 7s 76ms/step - loss: 1.2399 - acc: 0.7248 - val_loss: 1.3826 - val_acc: 0.6790
#
# Epoch 00084: val_acc did not improve from 0.71320
# Epoch 85/100
#  epoch=84, lr=0.09637, time_elapsed(s)=663.92
# 97/97 [==============================] - 7s 76ms/step - loss: 1.2083 - acc: 0.7291 - val_loss: 1.3565 - val_acc: 0.6840
#
# Epoch 00085: val_acc did not improve from 0.71320
# Epoch 86/100
#  epoch=85, lr=0.09085, time_elapsed(s)=671.27
# 97/97 [==============================] - 7s 76ms/step - loss: 1.1976 - acc: 0.7327 - val_loss: 1.4374 - val_acc: 0.6629
#
# Epoch 00086: val_acc did not improve from 0.71320
# Epoch 87/100
#  epoch=86, lr=0.08533, time_elapsed(s)=678.61
# 97/97 [==============================] - 7s 76ms/step - loss: 1.1822 - acc: 0.7363 - val_loss: 1.2744 - val_acc: 0.7026
#
# Epoch 00087: val_acc did not improve from 0.71320
# Epoch 88/100
#  epoch=87, lr=0.07981, time_elapsed(s)=685.96
# 97/97 [==============================] - 7s 75ms/step - loss: 1.2048 - acc: 0.7249 - val_loss: 1.3602 - val_acc: 0.6750
#
# Epoch 00088: val_acc did not improve from 0.71320
# Epoch 89/100
#  epoch=88, lr=0.07429, time_elapsed(s)=693.26
# 97/97 [==============================] - 7s 76ms/step - loss: 1.1644 - acc: 0.7377 - val_loss: 1.3369 - val_acc: 0.6820
#
# Epoch 00089: val_acc did not improve from 0.71320
# Epoch 90/100
#  epoch=89, lr=0.06877, time_elapsed(s)=700.65
# 97/97 [==============================] - 7s 76ms/step - loss: 1.1392 - acc: 0.7431 - val_loss: 1.4344 - val_acc: 0.6533
#
# Epoch 00090: val_acc did not improve from 0.71320
# Epoch 91/100
#  epoch=90, lr=0.06325, time_elapsed(s)=708.01
# 97/97 [==============================] - 7s 76ms/step - loss: 1.3262 - acc: 0.6788 - val_loss: 1.8877 - val_acc: 0.5093
#
# Epoch 00091: val_acc did not improve from 0.71320
# Epoch 92/100
#  epoch=91, lr=0.05773, time_elapsed(s)=715.38
# 97/97 [==============================] - 7s 76ms/step - loss: 1.2161 - acc: 0.7126 - val_loss: 1.3042 - val_acc: 0.6847
#
# Epoch 00092: val_acc did not improve from 0.71320
# Epoch 93/100
#  epoch=92, lr=0.05221, time_elapsed(s)=722.74
# 97/97 [==============================] - 7s 76ms/step - loss: 1.1486 - acc: 0.7348 - val_loss: 1.2886 - val_acc: 0.6969
#
# Epoch 00093: val_acc did not improve from 0.71320
# Epoch 94/100
#  epoch=93, lr=0.04669, time_elapsed(s)=730.10
# 97/97 [==============================] - 7s 76ms/step - loss: 1.1243 - acc: 0.7417 - val_loss: 1.3462 - val_acc: 0.6802
#
# Epoch 00094: val_acc did not improve from 0.71320
# Epoch 95/100
#  epoch=94, lr=0.04117, time_elapsed(s)=737.47
# 97/97 [==============================] - 7s 76ms/step - loss: 1.1018 - acc: 0.7464 - val_loss: 1.2466 - val_acc: 0.7063
#
# Epoch 00095: val_acc did not improve from 0.71320
# Epoch 96/100
#  epoch=95, lr=0.03565, time_elapsed(s)=744.81
# 97/97 [==============================] - 7s 76ms/step - loss: 1.0864 - acc: 0.7514 - val_loss: 1.2625 - val_acc: 0.6952
#
# Epoch 00096: val_acc did not improve from 0.71320
# Epoch 97/100
#  epoch=96, lr=0.03013, time_elapsed(s)=752.19
# 97/97 [==============================] - 7s 76ms/step - loss: 1.0640 - acc: 0.7581 - val_loss: 1.1862 - val_acc: 0.7198
#
# Epoch 00097: val_acc improved from 0.71320 to 0.71980, saving model to assignment_12_eva.hdf5
# Epoch 98/100
#  epoch=97, lr=0.02462, time_elapsed(s)=761.51
# 97/97 [==============================] - 8s 83ms/step - loss: 1.0368 - acc: 0.7644 - val_loss: 1.4046 - val_acc: 0.6576
#
# Epoch 00098: val_acc did not improve from 0.71980
# Epoch 99/100
#  epoch=98, lr=0.01910, time_elapsed(s)=769.58
# 97/97 [==============================] - 7s 76ms/step - loss: 1.0391 - acc: 0.7637 - val_loss: 1.9769 - val_acc: 0.5677
#
# Epoch 00099: val_acc did not improve from 0.71980
# Epoch 100/100
#  epoch=99, lr=0.01358, time_elapsed(s)=776.97
# 97/97 [==============================] - 7s 76ms/step - loss: 1.0389 - acc: 0.7635 - val_loss: 1.3081 - val_acc: 0.6837
#
# Epoch 00100: val_acc did not improve from 0.71980
# Model took 787.29 seconds to train
# Accuracy on test data is: 71.98

# %%
plt.plot(lr_manager.history['iterations'], lr_manager.history['lr'])
plt.xlabel('Training Iterations')
plt.ylabel('Momentum')
plt.title("One Cycle Policy")
plt.show()

plt.plot(lr_manager.history['iterations'], lr_manager.history['momentum'])
plt.xlabel('Training Iterations')
plt.ylabel('Momentum')
plt.title("One Cycle Policy")
plt.show()

# %% [markdown]
# # GradCam on mis-classified images

# %%
from google.colab.patches import cv2_imshow

from matplotlib import gridspec

from keras.preprocessing.image import img_to_array

import cv2

def get_gradcam(image_in, layer_name = "res5c_branch2c", num_kernels = 2048):
  

  #image_in = cv2.resize(image_in, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)

  x = img_to_array(image_in)

  x = x.reshape((1, image_in.shape[0], image_in.shape[1], image_in.shape[2]))

  #x = preprocess_input(x)

  preds = model.predict(x)

  class_idx = np.argmax(preds[0])

  #print(class_idx)

  class_output = model.output[:, class_idx]

  #print(imagenet_classes[class_idx])

  last_conv_layer = model.get_layer(layer_name)

  grads = K.gradients(class_output, last_conv_layer.output)[0]

  #print(grads.shape)

  pooled_grads = K.mean(grads, axis=(0, 1, 2))

  #print(pooled_grads.shape)

  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

  pooled_grads_value, conv_layer_output_value = iterate([x])

  for i in range(num_kernels):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

  heatmap = np.mean(conv_layer_output_value, axis = -1)

  #print(conv_layer_output_value.shape)

  #print(heatmap.shape)

  heatmap = np.maximum(heatmap, 0)

  heatmap /= np.max(heatmap)

  heatmap = cv2.resize(heatmap, (image_in.shape[1], image_in.shape[0]))

  heatmap = np.uint8(255 * heatmap)

  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

  superimposed_img = cv2.addWeighted(cv2.resize(image_in, dsize=(32, 32), interpolation=cv2.INTER_CUBIC), 0.5, heatmap, 0.5, 0, dtype = cv2.CV_32F)

  #cv2_imshow(image_in)

  #cv2_imshow(heatmap)

  #cv2_imshow(superimposed_img)
  
  return superimposed_img



def get_wrongly_classified_indices(predictions, y_vals):
  
  """
  Takes predicted and actual values
  Returns a tuple of misclassified image indexes and their corresponding predicted and actual values
  
  NOTE: Make sure your predictions are in the same order of actuals, using shuffle=False while predicting would be important
  
  Params:
  predictions: probability values of predictions
  y_vals: actual values of data
  """
  
  predicted_y = np.argmax(predictions, axis=1)
  
  actual_y = np.argmax(y_vals, axis = 1)
  
  wrong_indices = np.nonzero(~(actual_y == predicted_y))
  
  return (wrong_indices[0], predicted_y[wrong_indices[0]], actual_y[wrong_indices[0]])
  
  
def plot_figures(figures, nrows = 1, ncols=1):
    """Plot a dictionary of figures.

    Parameters
    ----------
    figures : <title, figure> dictionary
    ncols : number of columns of subplots wanted in the display
    nrows : number of rows of subplots wanted in the figure
    """

    fig = plt.figure(figsize=(15,20))
    
    gs = gridspec.GridSpec(ncols=ncols, nrows=nrows, wspace=0.4, hspace=0, top = 0.5, bottom  = 0)
    
    for ind,title in enumerate(figures):
        
        nested_gs = gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=gs[ind], wspace=0) # 1 row, 2 columns for each cluster
        
        ax = plt.Subplot(fig, nested_gs[0])
        
        
        ax.imshow(figures[title]["image"])
        
        fig.add_subplot(ax)
        
        ax.set_title(title)
        
        ax = plt.Subplot(fig, nested_gs[1])        
        
        ax.imshow(figures[title]["grad_cam"])
        
        fig.add_subplot(ax)
        
        
    plt.subplots_adjust(hspace = 0)
    plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

predictions = model.predict(test_features)
    
misclassified_image_idx = get_wrongly_classified_indices(predictions, test_labels)

print(misclassified_image_idx)

number_of_im = len(misclassified_image_idx[0])

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

if (number_of_im) > 25:
  number_of_im = 25

figures = {}

for i in range(number_of_im):
  
  title = str(i+1)+'.\tPredicted: '.expandtabs()+class_names[misclassified_image_idx[1][i]] + '\n\tActual: '.expandtabs() + class_names[misclassified_image_idx[2][i]]
  
  img_idx = misclassified_image_idx[0][i]
  
  image = test_features[img_idx].reshape(32,32,3)
  
  grad_cam = get_gradcam(image, layer_name = "batch_normalization_21", num_kernels = 512)
  
  figures[title] = {}
  
  figures[title]["image"] = image
  
  figures[title]["grad_cam"] = grad_cam
  
  #figures[title]["title"] = title
# Out:
# (array([  12,   24,   25, ..., 9993, 9995, 9999]), array([3, 3, 6, ..., 3, 0, 4]), array([5, 5, 2, ..., 5, 8, 7]))

# %%
#import warnings
#warnings.filterwarnings("ignore")

plot_figures(figures, 5, 5)
# Out:
# W0727 21:47:39.622476 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.645664 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.668377 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.691503 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.714463 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.736346 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.760164 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.783009 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.806414 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.828121 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.849912 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.871391 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.894497 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.919870 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.941667 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.963905 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:39.988145 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:40.013051 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:40.038519 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:40.062017 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:40.084975 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:40.108642 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:40.131287 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:40.155216 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0727 21:47:40.177641 139899605669760 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16, 16, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# res0a_branch2a (Conv2D)         (None, 4, 4, 64)     36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 4, 4, 64)     256         res0a_branch2a[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 4, 4, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 4, 4, 64)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4, 4, 64)     256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 4, 4, 64)     36928       activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4, 4, 64)     0           batch_normalization_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, 4, 64)     256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 4, 4, 64)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 64)     36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 4, 4, 64)     256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 4, 4, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 4, 64)     36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 4, 4, 64)     0           add_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 4, 64)     256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 4, 4, 64)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 2, 2, 128)    73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 2, 2, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 2, 2, 128)    8320        add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 2, 2, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 2, 2, 128)    512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 2, 2, 128)    147584      activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 2, 2, 128)    0           batch_normalization_8[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 2, 2, 128)    512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 2, 2, 128)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 2, 2, 128)    147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 2, 2, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 2, 2, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 2, 2, 128)    147584      activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 2, 2, 128)    0           add_3[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 2, 2, 128)    512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 1, 256)    295168      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 1, 1, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 256)    33024       add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 1, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 1, 1, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 1, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 1, 1, 256)    0           batch_normalization_13[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1, 1, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 1, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 1, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1, 1, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 1, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1, 1, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 1, 1, 256)    0           add_5[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1, 1, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 1, 1, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 1, 512)    1180160     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 1, 1, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 1, 512)    131584      add_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1, 1, 512)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 1, 1, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 1, 1, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 1, 1, 512)    0           batch_normalization_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 1, 1, 512)    2048        add_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1, 1, 512)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 1, 1, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 1, 1, 512)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 1, 512)    2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1, 1, 512)    0           add_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 1, 1, 512)    2048        add_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 1, 1, 512)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           activation_17[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 11,200,458
# Trainable params: 11,190,730
# Non-trainable params: 9,728
# __________________________________________________________________________________________________
