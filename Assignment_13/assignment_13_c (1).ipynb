# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')

root_path = 'gdrive/My Drive/Colab Notebooks/' #change dir to your project folder

os.chdir('/content/' + root_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import keras
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, AveragePooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

from clr import LR_Finder,OneCycleLR

from image_augmentation_utils import get_custom_augmentations

import resnet

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

from keras.layers import GlobalAveragePooling2D

from keras import optimizers

from keras import regularizers

from keras.callbacks import Callback

import cv2

from sklearn.metrics import accuracy_score

import numpy as np

import warnings

warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
train_labels_integer = train_labels

test_labels_integer = test_labels

for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels_integer[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(iterator, model):
    
    accuracy = model.evaluate_generator(iterator, steps=len(iterator))[1]
    return (accuracy * 100)
  
def tta_preds(img, model, data_gen, num_aug_images):
  
  img = img.reshape(1, img.shape[0], img.shape[1], img.shape[2])
  
  images = data_gen.flow(img, batch_size=num_aug_images)
  
  predictions = model.predict_generator(images, steps=num_aug_images)
  
  prediction_mean = np.mean(predictions, axis=0)
  
  return np.argmax(prediction_mean)


def tta_accuracy(model, X, Y, data_gen, num_aug_images=5):
  
  yhats=[]
  
  for i in range(len(X)):
      
        yhat = tta_preds(X[i], model, data_gen, num_aug_images)

        yhats.append(yhat)
    
  testY_labels = np.argmax(Y, axis=1)
    
  acc = accuracy_score(testY_labels, yhats)
    
  return acc

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
class showLR( Callback ) :
    
    time = time.time()
    
    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 0:
          self.time = time.time()
          
          print("time registered", self.time)
          
        current_time = time.time()
        
        time_taken = current_time - self.time
        lr = float(K.get_value(self.model.optimizer.lr))
        print(" epoch={:02d}, lr={:.5f}, time_elapsed(s)={:.2f}".format( epoch, lr, time_taken))

# %% [markdown]
# **Setting up DataAugmentation**

# %%
datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=True,
                             #featurewise_center=True,featurewise_std_normalization=True,
                            preprocessing_function=get_custom_augmentations(v_l=0, v_h=1, normalize = True, random_crop = True, cutout = True)
                            )


datagen.fit(train_features)

datagen_test = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=True,
                                  #featurewise_center=True,featurewise_std_normalization=True,
                            preprocessing_function=get_custom_augmentations(v_l=0, v_h=1, normalize = True, random_crop = False, cutout = False)
                            )


datagen_test.fit(test_features)



iterator = datagen.flow(train_features, train_labels, batch_size = train_features.shape[0])

X_train_da, y_train_da = iterator.next()

iterator_test = datagen_test.flow(test_features, test_labels, batch_size = test_features.shape[0], shuffle = True)

X_test_da, y_test_da = iterator_test.next()

# %% [markdown]
# **Visualizing augmented images**

# %%
import random

random_images_tolook = [random.randint(0,X_train_da.shape[0]) for x in range(15)]

actual_y = np.argmax(y_train_da, axis=1)

fig, axeslist = plt.subplots(ncols = 3, nrows = len(random_images_tolook)//3 , figsize=(15,8))

for ind in range(len(random_images_tolook)):
  
  axeslist.ravel()[ind].imshow(X_train_da[random_images_tolook[ind]])
  
  axeslist.ravel()[ind].set_title(class_names[actual_y[random_images_tolook[ind]]])
  
plt.subplots_adjust(hspace = 0.5)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0730 06:54:26.296149 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.299270 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.302571 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.307846 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.311792 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.315447 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.318850 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.322563 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.326076 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.329510 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.332999 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.336600 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.342555 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.346597 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0730 06:54:26.350683 139724577154944 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Define the model

model = resnet.ResNet18((train_features.shape[1], train_features.shape[2], train_features.shape[3]), 10)

model.summary()
# Out:
# W0730 06:54:43.150123 139724577154944 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0730 06:54:43.188523 139724577154944 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0730 06:54:43.196802 139724577154944 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0730 06:54:43.246850 139724577154944 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0730 06:54:43.248369 139724577154944 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0730 06:54:45.991086 139724577154944 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0730 06:54:46.284161 139724577154944 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# reshaping via a convolution...
# reshaping via a convolution...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   4640        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   18496       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# res0a_branch2a (Conv2D)         (None, 16, 16, 64)   36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         res0a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 64)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 64)   0           add_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 64)   0           add_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 128)    73856       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 128)    8320        add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 128)    147584      activation_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 128)    0           batch_normalization_11[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 128)    512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 128)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 128)    147584      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 128)    512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 128)    147584      activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 128)    0           add_4[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 128)    512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    147584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 128)    0           add_5[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 128)    512         add_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 256)    295168      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 256)    1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 256)    33024       add_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 256)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 256)    1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 256)    590080      activation_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 256)    0           batch_normalization_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 256)    1024        add_7[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 256)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 256)    590080      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, 4, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 256)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    590080      activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 256)    0           add_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 256)    1024        add_8[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           activation_19[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 3,176,938
# Trainable params: 3,171,594
# Non-trainable params: 5,344
# __________________________________________________________________________________________________

# %%
# Compile the model

sgd = optimizers.SGD(lr=0.01,  momentum=0.9)


model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

# train the model
start = time.time()
# Train the model

bs = int(128)


step_size_clr = int(train_features.shape[0])//bs

lr_finder = LR_Finder(start_lr=1e-8, end_lr=10, step_size=step_size_clr)

"""
lr_finder = LRFinder(train_features.shape[0], bs,
                       1e-3, 1,
                       # validation_data=(X_val, Y_val),
                       lr_scale='exp', save_dir='.', verbose=0)
                       
"""
                       



model_info = model.fit_generator(datagen.flow(X_train_da, y_train_da, batch_size = bs),
                                 samples_per_epoch = train_features.shape[0], 
                                 callbacks=[lr_finder] ,verbose=0)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

#lr_finder.plot_schedule()
lr_finder.plot_smoothed_loss()
# Out:
# W0730 06:55:56.987740 139724577154944 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0730 06:55:57.454893 139724577154944 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model took 91.23 seconds to train

# %% [markdown]
# **Setting up the learning rate and callbacks**

# %%
epochs = 150
max_lr = 0.1
base_lr = 0.01
max_m = 0.95
base_m = 0.85
end_percentage = 0.2

cyclical_momentum = True

decayrate = base_lr/epochs

lr_manager = OneCycleLR( max_lr = max_lr, batch_size = bs, samples = train_features.shape[0],
                        end_percentage=end_percentage, scale_percentage=None,
                        maximum_momentum=max_m, minimum_momentum=base_m)

#lr_manager = CyclicLR(base_lr = .003, max_lr = 0.1, step_size = step_size_clr, mode="triangular")
"""
lr_manager =  CyclicLR(base_lr=base_lr,
                max_lr=max_lr,
                step_size=step_size_clr,
                max_m=max_m,
                base_m=base_m,
                cyclical_momentum=cyclical_momentum)
                
"""

filepath = "assignment_13c_eva.hdf5"

checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

sgd = optimizers.SGD(lr=base_lr,  momentum=0.9, decay=decayrate)

showlr = showLR()

# %% [markdown]
# **Train for 150 epochs with cyclic LR**

# %%
model.load_weights(filepath)
test_iterator = datagen_test.flow(test_features, test_labels, batch_size = bs, shuffle = False)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_iterator, model))
# Out:
# Accuracy on test data is: 94.75

# %%
sgd = optimizers.SGD(lr=base_lr,  momentum=0.9, decay=decayrate)


print(K.get_value(model.optimizer.lr))


model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

print(K.get_value(model.optimizer.lr))


# train the model
start = time.time()

test_iterator = datagen_test.flow(test_features, test_labels, batch_size = bs, shuffle = False)

model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = bs),
                                 samples_per_epoch = int(train_features.shape[0]), nb_epoch = epochs, 
                                 validation_data = test_iterator,
                                 validation_steps = len(test_iterator),
                                 callbacks=[checkpoint, lr_manager, showlr] ,verbose=1)

end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(model_info)

model.load_weights(filepath)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_iterator, model))
# Out:
# 10.0
# 0.01
# Epoch 1/150
# time registered 1564390601.3869712
#  epoch=00, lr=0.02000, time_elapsed(s)=0.00
# 390/390 [==============================] - 62s 160ms/step - loss: 2.3345 - acc: 0.3046 - val_loss: 2.1411 - val_acc: 0.3658
#
# Epoch 00001: val_acc improved from -inf to 0.36580, saving model to assignment_13c_eva.hdf5
#  - lr: 0.02632 - momentum: 0.95
# Epoch 2/150
#  epoch=01, lr=0.02633, time_elapsed(s)=66.07
# 390/390 [==============================] - 60s 154ms/step - loss: 2.0203 - acc: 0.4175 - val_loss: 2.0396 - val_acc: 0.4000
#
# Epoch 00002: val_acc improved from 0.36580 to 0.40000, saving model to assignment_13c_eva.hdf5
#  - lr: 0.03265 - momentum: 0.95
# Epoch 3/150
#  epoch=02, lr=0.03267, time_elapsed(s)=126.89
# 390/390 [==============================] - 59s 152ms/step - loss: 1.8050 - acc: 0.4938 - val_loss: 1.7130 - val_acc: 0.5218
#
# Epoch 00003: val_acc improved from 0.40000 to 0.52180, saving model to assignment_13c_eva.hdf5
#  - lr: 0.03898 - momentum: 0.95
# Epoch 4/150
#  epoch=03, lr=0.03900, time_elapsed(s)=187.22
# 390/390 [==============================] - 60s 153ms/step - loss: 1.6004 - acc: 0.5633 - val_loss: 1.5358 - val_acc: 0.5802
#
# Epoch 00004: val_acc improved from 0.52180 to 0.58020, saving model to assignment_13c_eva.hdf5
#  - lr: 0.04532 - momentum: 0.94
# Epoch 5/150
#  epoch=04, lr=0.04533, time_elapsed(s)=247.63
# 390/390 [==============================] - 59s 152ms/step - loss: 1.4522 - acc: 0.6071 - val_loss: 1.4348 - val_acc: 0.6167
#
# Epoch 00005: val_acc improved from 0.58020 to 0.61670, saving model to assignment_13c_eva.hdf5
#  - lr: 0.05165 - momentum: 0.94
# Epoch 6/150
#  epoch=05, lr=0.05167, time_elapsed(s)=308.19
# 390/390 [==============================] - 60s 153ms/step - loss: 1.3029 - acc: 0.6535 - val_loss: 1.2193 - val_acc: 0.6776
#
# Epoch 00006: val_acc improved from 0.61670 to 0.67760, saving model to assignment_13c_eva.hdf5
#  - lr: 0.05798 - momentum: 0.94
# Epoch 7/150
#  epoch=06, lr=0.05800, time_elapsed(s)=368.65
# 390/390 [==============================] - 59s 152ms/step - loss: 1.1910 - acc: 0.6852 - val_loss: 1.1849 - val_acc: 0.6828
#
# Epoch 00007: val_acc improved from 0.67760 to 0.68280, saving model to assignment_13c_eva.hdf5
#  - lr: 0.06432 - momentum: 0.94
# Epoch 8/150
#  epoch=07, lr=0.06433, time_elapsed(s)=428.87
# 390/390 [==============================] - 60s 153ms/step - loss: 1.0967 - acc: 0.7156 - val_loss: 1.5064 - val_acc: 0.6294
#
# Epoch 00008: val_acc did not improve from 0.68280
#  - lr: 0.07065 - momentum: 0.94
# Epoch 9/150
#  epoch=08, lr=0.07067, time_elapsed(s)=488.51
# 390/390 [==============================] - 60s 153ms/step - loss: 1.0171 - acc: 0.7373 - val_loss: 1.0747 - val_acc: 0.7196
#
# Epoch 00009: val_acc improved from 0.68280 to 0.71960, saving model to assignment_13c_eva.hdf5
#  - lr: 0.07698 - momentum: 0.94
# Epoch 10/150
#  epoch=09, lr=0.07700, time_elapsed(s)=549.03
# 390/390 [==============================] - 60s 153ms/step - loss: 0.9575 - acc: 0.7561 - val_loss: 1.5049 - val_acc: 0.6081
#
# Epoch 00010: val_acc did not improve from 0.71960
#  - lr: 0.08332 - momentum: 0.93
# Epoch 11/150
#  epoch=10, lr=0.08333, time_elapsed(s)=608.60
# 390/390 [==============================] - 60s 153ms/step - loss: 0.9068 - acc: 0.7705 - val_loss: 1.1250 - val_acc: 0.7238
#
# Epoch 00011: val_acc improved from 0.71960 to 0.72380, saving model to assignment_13c_eva.hdf5
#  - lr: 0.08965 - momentum: 0.93
# Epoch 12/150
#  epoch=11, lr=0.08967, time_elapsed(s)=669.01
# 390/390 [==============================] - 60s 153ms/step - loss: 0.8636 - acc: 0.7827 - val_loss: 1.0718 - val_acc: 0.7190
#
# Epoch 00012: val_acc did not improve from 0.72380
#  - lr: 0.09598 - momentum: 0.93
# Epoch 13/150
#  epoch=12, lr=0.09600, time_elapsed(s)=728.60
# 390/390 [==============================] - 60s 153ms/step - loss: 0.8387 - acc: 0.7897 - val_loss: 0.9721 - val_acc: 0.7516
#
# Epoch 00013: val_acc improved from 0.72380 to 0.75160, saving model to assignment_13c_eva.hdf5
#  - lr: 0.10232 - momentum: 0.93
# Epoch 14/150
#  epoch=13, lr=0.10233, time_elapsed(s)=789.33
# 390/390 [==============================] - 59s 153ms/step - loss: 0.8060 - acc: 0.8008 - val_loss: 1.1078 - val_acc: 0.7169
#
# Epoch 00014: val_acc did not improve from 0.75160
#  - lr: 0.10865 - momentum: 0.93
# Epoch 15/150
#  epoch=14, lr=0.10867, time_elapsed(s)=848.82
# 390/390 [==============================] - 59s 152ms/step - loss: 0.7764 - acc: 0.8095 - val_loss: 1.2932 - val_acc: 0.6851
#
# Epoch 00015: val_acc did not improve from 0.75160
#  - lr: 0.11498 - momentum: 0.93
# Epoch 16/150
#  epoch=15, lr=0.11500, time_elapsed(s)=908.15
# 390/390 [==============================] - 60s 153ms/step - loss: 0.7622 - acc: 0.8137 - val_loss: 0.8266 - val_acc: 0.7987
#
# Epoch 00016: val_acc improved from 0.75160 to 0.79870, saving model to assignment_13c_eva.hdf5
#  - lr: 0.12132 - momentum: 0.92
# Epoch 17/150
#  epoch=16, lr=0.12133, time_elapsed(s)=968.76
# 390/390 [==============================] - 60s 153ms/step - loss: 0.7440 - acc: 0.8213 - val_loss: 1.3151 - val_acc: 0.6921
#
# Epoch 00017: val_acc did not improve from 0.79870
#  - lr: 0.12765 - momentum: 0.92
# Epoch 18/150
#  epoch=17, lr=0.12767, time_elapsed(s)=1028.49
# 390/390 [==============================] - 60s 153ms/step - loss: 0.7271 - acc: 0.8281 - val_loss: 1.1699 - val_acc: 0.7188
#
# Epoch 00018: val_acc did not improve from 0.79870
#  - lr: 0.13398 - momentum: 0.92
# Epoch 19/150
#  epoch=18, lr=0.13400, time_elapsed(s)=1088.01
# 390/390 [==============================] - 60s 153ms/step - loss: 0.7163 - acc: 0.8302 - val_loss: 1.6942 - val_acc: 0.6333
#
# Epoch 00019: val_acc did not improve from 0.79870
#  - lr: 0.14032 - momentum: 0.92
# Epoch 20/150
#  epoch=19, lr=0.14033, time_elapsed(s)=1147.55
# 390/390 [==============================] - 60s 153ms/step - loss: 0.7070 - acc: 0.8364 - val_loss: 0.9584 - val_acc: 0.7623
#
# Epoch 00020: val_acc did not improve from 0.79870
#  - lr: 0.14665 - momentum: 0.92
# Epoch 21/150
#  epoch=20, lr=0.14667, time_elapsed(s)=1207.17
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6958 - acc: 0.8406 - val_loss: 0.9088 - val_acc: 0.7770
#
# Epoch 00021: val_acc did not improve from 0.79870
#  - lr: 0.15298 - momentum: 0.92
# Epoch 22/150
#  epoch=21, lr=0.15300, time_elapsed(s)=1266.79
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6941 - acc: 0.8415 - val_loss: 0.8390 - val_acc: 0.8063
#
# Epoch 00022: val_acc improved from 0.79870 to 0.80630, saving model to assignment_13c_eva.hdf5
#  - lr: 0.15932 - momentum: 0.91
# Epoch 23/150
#  epoch=22, lr=0.15933, time_elapsed(s)=1327.28
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6858 - acc: 0.8464 - val_loss: 1.0061 - val_acc: 0.7568
#
# Epoch 00023: val_acc did not improve from 0.80630
#  - lr: 0.16565 - momentum: 0.91
# Epoch 24/150
#  epoch=23, lr=0.16567, time_elapsed(s)=1386.96
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6726 - acc: 0.8497 - val_loss: 0.8442 - val_acc: 0.8132
#
# Epoch 00024: val_acc improved from 0.80630 to 0.81320, saving model to assignment_13c_eva.hdf5
#  - lr: 0.17198 - momentum: 0.91
# Epoch 25/150
#  epoch=24, lr=0.17200, time_elapsed(s)=1447.30
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6757 - acc: 0.8521 - val_loss: 0.9569 - val_acc: 0.7538
#
# Epoch 00025: val_acc did not improve from 0.81320
#  - lr: 0.17832 - momentum: 0.91
# Epoch 26/150
#  epoch=25, lr=0.17833, time_elapsed(s)=1506.81
# 390/390 [==============================] - 59s 152ms/step - loss: 0.6651 - acc: 0.8560 - val_loss: 0.8139 - val_acc: 0.8142
#
# Epoch 00026: val_acc improved from 0.81320 to 0.81420, saving model to assignment_13c_eva.hdf5
#  - lr: 0.18465 - momentum: 0.91
# Epoch 27/150
#  epoch=26, lr=0.18467, time_elapsed(s)=1567.12
# 390/390 [==============================] - 59s 152ms/step - loss: 0.6655 - acc: 0.8584 - val_loss: 0.8264 - val_acc: 0.8129
#
# Epoch 00027: val_acc did not improve from 0.81420
#  - lr: 0.19098 - momentum: 0.91
# Epoch 28/150
#  epoch=27, lr=0.19100, time_elapsed(s)=1626.54
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6633 - acc: 0.8591 - val_loss: 0.8328 - val_acc: 0.8172
#
# Epoch 00028: val_acc improved from 0.81420 to 0.81720, saving model to assignment_13c_eva.hdf5
#  - lr: 0.19732 - momentum: 0.90
# Epoch 29/150
#  epoch=28, lr=0.19733, time_elapsed(s)=1687.05
# 390/390 [==============================] - 59s 152ms/step - loss: 0.6549 - acc: 0.8620 - val_loss: 0.7308 - val_acc: 0.8446
#
# Epoch 00029: val_acc improved from 0.81720 to 0.84460, saving model to assignment_13c_eva.hdf5
#  - lr: 0.20365 - momentum: 0.90
# Epoch 30/150
#  epoch=29, lr=0.20367, time_elapsed(s)=1747.26
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6524 - acc: 0.8657 - val_loss: 0.7970 - val_acc: 0.8253
#
# Epoch 00030: val_acc did not improve from 0.84460
#  - lr: 0.20998 - momentum: 0.90
# Epoch 31/150
#  epoch=30, lr=0.21000, time_elapsed(s)=1806.86
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6497 - acc: 0.8658 - val_loss: 0.9852 - val_acc: 0.7785
#
# Epoch 00031: val_acc did not improve from 0.84460
#  - lr: 0.21632 - momentum: 0.90
# Epoch 32/150
#  epoch=31, lr=0.21633, time_elapsed(s)=1866.38
# 390/390 [==============================] - 59s 152ms/step - loss: 0.6401 - acc: 0.8698 - val_loss: 0.8156 - val_acc: 0.8204
#
# Epoch 00032: val_acc did not improve from 0.84460
#  - lr: 0.22265 - momentum: 0.90
# Epoch 33/150
#  epoch=32, lr=0.22267, time_elapsed(s)=1925.79
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6422 - acc: 0.8707 - val_loss: 0.7405 - val_acc: 0.8456
#
# Epoch 00033: val_acc improved from 0.84460 to 0.84560, saving model to assignment_13c_eva.hdf5
#  - lr: 0.22898 - momentum: 0.90
# Epoch 34/150
#  epoch=33, lr=0.22900, time_elapsed(s)=1986.23
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6323 - acc: 0.8752 - val_loss: 0.7925 - val_acc: 0.8263
#
# Epoch 00034: val_acc did not improve from 0.84560
#  - lr: 0.23532 - momentum: 0.89
# Epoch 35/150
#  epoch=34, lr=0.23533, time_elapsed(s)=2045.91
# 390/390 [==============================] - 59s 152ms/step - loss: 0.6383 - acc: 0.8732 - val_loss: 0.8604 - val_acc: 0.8133
#
# Epoch 00035: val_acc did not improve from 0.84560
#  - lr: 0.24165 - momentum: 0.89
# Epoch 36/150
#  epoch=35, lr=0.24167, time_elapsed(s)=2105.37
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6324 - acc: 0.8758 - val_loss: 1.0106 - val_acc: 0.7766
#
# Epoch 00036: val_acc did not improve from 0.84560
#  - lr: 0.24798 - momentum: 0.89
# Epoch 37/150
#  epoch=36, lr=0.24800, time_elapsed(s)=2164.97
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6271 - acc: 0.8791 - val_loss: 0.7672 - val_acc: 0.8445
#
# Epoch 00037: val_acc did not improve from 0.84560
#  - lr: 0.25432 - momentum: 0.89
# Epoch 38/150
#  epoch=37, lr=0.25433, time_elapsed(s)=2224.49
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6365 - acc: 0.8771 - val_loss: 0.8392 - val_acc: 0.8201
#
# Epoch 00038: val_acc did not improve from 0.84560
#  - lr: 0.26065 - momentum: 0.89
# Epoch 39/150
#  epoch=38, lr=0.26067, time_elapsed(s)=2284.03
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6312 - acc: 0.8802 - val_loss: 0.7663 - val_acc: 0.8405
#
# Epoch 00039: val_acc did not improve from 0.84560
#  - lr: 0.26698 - momentum: 0.89
# Epoch 40/150
#  epoch=39, lr=0.26700, time_elapsed(s)=2343.66
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6243 - acc: 0.8825 - val_loss: 1.0683 - val_acc: 0.7897
#
# Epoch 00040: val_acc did not improve from 0.84560
#  - lr: 0.27332 - momentum: 0.88
# Epoch 41/150
#  epoch=40, lr=0.27333, time_elapsed(s)=2403.27
# 390/390 [==============================] - 59s 152ms/step - loss: 0.6262 - acc: 0.8806 - val_loss: 0.7695 - val_acc: 0.8398
#
# Epoch 00041: val_acc did not improve from 0.84560
#  - lr: 0.27965 - momentum: 0.88
# Epoch 42/150
#  epoch=41, lr=0.27967, time_elapsed(s)=2462.73
# 390/390 [==============================] - 59s 152ms/step - loss: 0.6158 - acc: 0.8861 - val_loss: 1.0616 - val_acc: 0.7682
#
# Epoch 00042: val_acc did not improve from 0.84560
#  - lr: 0.28598 - momentum: 0.88
# Epoch 43/150
#  epoch=42, lr=0.28600, time_elapsed(s)=2522.19
# 390/390 [==============================] - 59s 152ms/step - loss: 0.6163 - acc: 0.8861 - val_loss: 0.7870 - val_acc: 0.8443
#
# Epoch 00043: val_acc did not improve from 0.84560
#  - lr: 0.29232 - momentum: 0.88
# Epoch 44/150
#  epoch=43, lr=0.29233, time_elapsed(s)=2581.65
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6198 - acc: 0.8857 - val_loss: 0.8431 - val_acc: 0.8234
#
# Epoch 00044: val_acc did not improve from 0.84560
#  - lr: 0.29865 - momentum: 0.88
# Epoch 45/150
#  epoch=44, lr=0.29867, time_elapsed(s)=2641.15
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6115 - acc: 0.8893 - val_loss: 0.7077 - val_acc: 0.8635
#
# Epoch 00045: val_acc improved from 0.84560 to 0.86350, saving model to assignment_13c_eva.hdf5
#  - lr: 0.30498 - momentum: 0.88
# Epoch 46/150
#  epoch=45, lr=0.30500, time_elapsed(s)=2701.82
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6136 - acc: 0.8894 - val_loss: 0.7686 - val_acc: 0.8505
#
# Epoch 00046: val_acc did not improve from 0.86350
#  - lr: 0.31132 - momentum: 0.87
# Epoch 47/150
#  epoch=46, lr=0.31133, time_elapsed(s)=2761.50
# 390/390 [==============================] - 59s 153ms/step - loss: 0.6149 - acc: 0.8885 - val_loss: 0.7388 - val_acc: 0.8557
#
# Epoch 00047: val_acc did not improve from 0.86350
#  - lr: 0.31765 - momentum: 0.87
# Epoch 48/150
#  epoch=47, lr=0.31767, time_elapsed(s)=2820.99
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6115 - acc: 0.8896 - val_loss: 0.9246 - val_acc: 0.8112
#
# Epoch 00048: val_acc did not improve from 0.86350
#  - lr: 0.32398 - momentum: 0.87
# Epoch 49/150
#  epoch=48, lr=0.32400, time_elapsed(s)=2880.52
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6090 - acc: 0.8917 - val_loss: 0.7184 - val_acc: 0.8633
#
# Epoch 00049: val_acc did not improve from 0.86350
#  - lr: 0.33032 - momentum: 0.87
# Epoch 50/150
#  epoch=49, lr=0.33033, time_elapsed(s)=2940.08
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6073 - acc: 0.8917 - val_loss: 0.7545 - val_acc: 0.8531
#
# Epoch 00050: val_acc did not improve from 0.86350
#  - lr: 0.33665 - momentum: 0.87
# Epoch 51/150
#  epoch=50, lr=0.33667, time_elapsed(s)=2999.67
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6086 - acc: 0.8911 - val_loss: 0.8372 - val_acc: 0.8254
#
# Epoch 00051: val_acc did not improve from 0.86350
#  - lr: 0.34298 - momentum: 0.87
# Epoch 52/150
#  epoch=51, lr=0.34300, time_elapsed(s)=3059.30
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6049 - acc: 0.8943 - val_loss: 1.2151 - val_acc: 0.7498
#
# Epoch 00052: val_acc did not improve from 0.86350
#  - lr: 0.34932 - momentum: 0.86
# Epoch 53/150
#  epoch=52, lr=0.34933, time_elapsed(s)=3118.97
# 390/390 [==============================] - 60s 153ms/step - loss: 0.6046 - acc: 0.8933 - val_loss: 0.8316 - val_acc: 0.8413
#
# Epoch 00053: val_acc did not improve from 0.86350
#  - lr: 0.35565 - momentum: 0.86
# Epoch 54/150
#  epoch=53, lr=0.35567, time_elapsed(s)=3178.51
# 390/390 [==============================] - 59s 152ms/step - loss: 0.5991 - acc: 0.8955 - val_loss: 0.9470 - val_acc: 0.8072
#
# Epoch 00054: val_acc did not improve from 0.86350
#  - lr: 0.36198 - momentum: 0.86
# Epoch 55/150
#  epoch=54, lr=0.36200, time_elapsed(s)=3237.95
# 390/390 [==============================] - 59s 153ms/step - loss: 0.6000 - acc: 0.8950 - val_loss: 0.7068 - val_acc: 0.8679
#
# Epoch 00055: val_acc improved from 0.86350 to 0.86790, saving model to assignment_13c_eva.hdf5
#  - lr: 0.36832 - momentum: 0.86
# Epoch 56/150
#  epoch=55, lr=0.36833, time_elapsed(s)=3298.42
# 390/390 [==============================] - 60s 153ms/step - loss: 0.5989 - acc: 0.8964 - val_loss: 0.9124 - val_acc: 0.8203
#
# Epoch 00056: val_acc did not improve from 0.86790
#  - lr: 0.37465 - momentum: 0.86
# Epoch 57/150
#  epoch=56, lr=0.37467, time_elapsed(s)=3358.09
# 390/390 [==============================] - 59s 152ms/step - loss: 0.5959 - acc: 0.8979 - val_loss: 0.7513 - val_acc: 0.8571
#
# Epoch 00057: val_acc did not improve from 0.86790
#  - lr: 0.38098 - momentum: 0.86
# Epoch 58/150
#  epoch=57, lr=0.38100, time_elapsed(s)=3417.51
# 390/390 [==============================] - 59s 152ms/step - loss: 0.5905 - acc: 0.8987 - val_loss: 0.7193 - val_acc: 0.8655
#
# Epoch 00058: val_acc did not improve from 0.86790
#  - lr: 0.38732 - momentum: 0.85
# Epoch 59/150
#  epoch=58, lr=0.38733, time_elapsed(s)=3476.79
# 390/390 [==============================] - 59s 152ms/step - loss: 0.5925 - acc: 0.8996 - val_loss: 0.7883 - val_acc: 0.8465
#
# Epoch 00059: val_acc did not improve from 0.86790
#  - lr: 0.39365 - momentum: 0.85
# Epoch 60/150
#  epoch=59, lr=0.39367, time_elapsed(s)=3536.21
# 390/390 [==============================] - 59s 153ms/step - loss: 0.5899 - acc: 0.9006 - val_loss: 0.8268 - val_acc: 0.8324
#
# Epoch 00060: val_acc did not improve from 0.86790
#  - lr: 0.39998 - momentum: 0.85
# Epoch 61/150
#  epoch=60, lr=0.40000, time_elapsed(s)=3595.69
#   5/390 [..............................] - ETA: 56s - loss: 0.6073 - acc: 0.8875

# %% [markdown]
# **Test time augmentation score**

# %%
#model.load_weights(filepath)

num_aug_images_tta = 15

tta_accuracy(model, test_features, test_labels,  datagen_test, num_aug_images = num_aug_images_tta)
# Out:
# 0.9514

# %% [markdown]
# # GradCam on mis-classified images

# %%
from google.colab.patches import cv2_imshow

from matplotlib import gridspec

from keras.preprocessing.image import img_to_array

import cv2

def get_gradcam(image_in, layer_name = "res5c_branch2c", num_kernels = 2048):
  

  #image_in = cv2.resize(image_in, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)

  x = img_to_array(image_in)

  x = x.reshape((1, image_in.shape[0], image_in.shape[1], image_in.shape[2]))

  #x = preprocess_input(x)

  preds = model.predict(x)

  class_idx = np.argmax(preds[0])

  #print(class_idx)

  class_output = model.output[:, class_idx]

  #print(imagenet_classes[class_idx])

  last_conv_layer = model.get_layer(layer_name)

  grads = K.gradients(class_output, last_conv_layer.output)[0]

  #print(grads.shape)

  pooled_grads = K.mean(grads, axis=(0, 1, 2))

  #print(pooled_grads.shape)

  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

  pooled_grads_value, conv_layer_output_value = iterate([x])

  for i in range(num_kernels):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

  heatmap = np.mean(conv_layer_output_value, axis = -1)

  #print(conv_layer_output_value.shape)

  #print(heatmap.shape)

  heatmap = np.maximum(heatmap, 0)

  heatmap /= np.max(heatmap)

  heatmap = cv2.resize(heatmap, (image_in.shape[1], image_in.shape[0]))

  heatmap = np.uint8(255 * heatmap)

  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

  superimposed_img = cv2.addWeighted(cv2.resize(image_in, dsize=(32, 32), interpolation=cv2.INTER_CUBIC), 0.5, heatmap, 0.5, 0, dtype = cv2.CV_32F)

  #cv2_imshow(image_in)

  #cv2_imshow(heatmap)

  #cv2_imshow(superimposed_img)
  
  return superimposed_img



def get_wrongly_classified_indices(predictions, y_vals):
  
  """
  Takes predicted and actual values
  Returns a tuple of misclassified image indexes and their corresponding predicted and actual values
  
  NOTE: Make sure your predictions are in the same order of actuals, using shuffle=False while predicting would be important
  
  Params:
  predictions: probability values of predictions
  y_vals: actual values of data
  """
  
  predicted_y = np.argmax(predictions, axis=1)
  
  actual_y = np.argmax(y_vals, axis = 1)
  
  wrong_indices = np.nonzero(~(actual_y == predicted_y))
  
  return (wrong_indices[0], predicted_y[wrong_indices[0]], actual_y[wrong_indices[0]])
  
  
def plot_figures(figures, nrows = 1, ncols=1):
    """Plot a dictionary of figures.

    Parameters
    ----------
    figures : <title, figure> dictionary
    ncols : number of columns of subplots wanted in the display
    nrows : number of rows of subplots wanted in the figure
    """

    fig = plt.figure(figsize=(15,20))
    
    gs = gridspec.GridSpec(ncols=ncols, nrows=nrows, wspace=0.4, hspace=0, top = 0.5, bottom  = 0)
    
    for ind,title in enumerate(figures):
        
        nested_gs = gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=gs[ind], wspace=0) # 1 row, 2 columns for each cluster
        
        ax = plt.Subplot(fig, nested_gs[0])
        
        
        ax.imshow(figures[title]["image"])
        
        fig.add_subplot(ax)
        
        ax.set_title(title)
        
        ax = plt.Subplot(fig, nested_gs[1])        
        
        ax.imshow(figures[title]["grad_cam"])
        
        fig.add_subplot(ax)
        
        
    plt.subplots_adjust(hspace = 0)
    plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

predictions = model.predict(test_features)
    
misclassified_image_idx = get_wrongly_classified_indices(predictions, test_labels)

print(misclassified_image_idx)

number_of_im = len(misclassified_image_idx[0])

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

if (number_of_im) > 25:
  number_of_im = 25

figures = {}

for i in range(number_of_im):
  
  title = str(i+1)+'.\tPredicted: '.expandtabs()+class_names[misclassified_image_idx[1][i]] + '\n\tActual: '.expandtabs() + class_names[misclassified_image_idx[2][i]]
  
  img_idx = misclassified_image_idx[0][i]
  
  image = test_features[img_idx].reshape(32,32,3)
  
  grad_cam = get_gradcam(image, layer_name = "conv2d_20", num_kernels = 256)
  
  figures[title] = {}
  
  figures[title]["image"] = image
  
  figures[title]["grad_cam"] = grad_cam
  
  #figures[title]["title"] = title

# %%
plot_figures(figures, 5, 5)
